# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("laptop_data_kaggle.csv")
df.sample(5)
# Out:
#       Unnamed: 0  Company     TypeName  Inches             ScreenResolution  \
# 1291        1291     Acer     Notebook    15.6                     1366x768
# 895          895  Toshiba     Notebook    13.3            Full HD 1920x1080
# 452          452       HP  Workstation    15.6  IPS Panel Full HD 1920x1080
# 705          705     Dell     Notebook    15.6            Full HD 1920x1080
# 897          897       HP     Notebook    15.6            Full HD 1920x1080
#
#                                        Cpu  Ram     Memory  \
# 1291  Intel Celeron Dual Core N3060 1.6GHz  4GB  500GB HDD
# 895             Intel Core i5 7200U 2.5GHz  8GB  256GB SSD
# 452            Intel Core i7 7820HQ 2.9GHz  8GB  512GB SSD
# 705             Intel Core i5 7200U 2.5GHz  8GB  256GB SSD
# 897             Intel Core i7 7500U 2.7GHz  8GB    1TB HDD
#
#                         Gpu       OpSys  Weight     Price
# 1291  Intel HD Graphics 400       Linux   2.4kg  15397.92
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df.columns = df.columns.str.replace(' ',"_").str.lower()
df.columns
# Out:
# Index(['company', 'typename', 'inches', 'screenresolution', 'cpu', 'ram',
#        'memory', 'gpu', 'opsys', 'weight', 'price'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# company             0
# typename            0
# inches              0
# screenresolution    0
# cpu                 0
# ram                 0
# memory              0
# gpu                 0
# opsys               0
# weight              0
# price               0
# dtype: int64

# %%
df.sample(5)
# Out:
#      company   typename  inches                 screenresolution  \
# 733     Acer   Notebook    15.6                         1366x768
# 1189    Acer     Gaming    17.3      IPS Panel Full HD 1920x1080
# 1083      HP  Ultrabook    13.3  IPS Panel 4K Ultra HD 3840x2160
# 1169     MSI     Gaming    15.6      IPS Panel Full HD 1920x1080
# 1109    Asus     Gaming    15.6      IPS Panel Full HD 1920x1080
#
#                               cpu   ram                memory  \
# 733    Intel Core i5 7200U 2.5GHz   4GB             500GB HDD
# 1189  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 1083   Intel Core i7 7500U 2.7GHz  16GB             512GB SSD
# 1169   Intel Core i7 7500U 2.7GHz   8GB               1TB HDD
# 1109  Intel Core i7 6700HQ 2.6GHz  16GB  128GB SSD +  1TB HDD
#
#                           gpu       opsys  weight      price
# 733     Intel HD Graphics 620  Windows 10   2.4kg   29783.52
# 1189  Nvidia GeForce GTX 1070  Windows 10   4.2kg  138474.72
# ...

# %%
df['ram'] = df['ram'].str.replace('GB',"")

# %%
df.sample(5)
# Out:
#     company  typename  inches             screenresolution  \
# 577  Lenovo    Gaming    17.3  IPS Panel Full HD 1920x1080
# 224    Dell    Gaming    17.3  IPS Panel Full HD 1920x1080
# 78     Acer  Notebook    15.6            Full HD 1920x1080
# 189    Dell  Notebook    17.3            Full HD 1920x1080
# 372    Asus    Gaming    17.3  IPS Panel Full HD 1920x1080
#
#                              cpu ram                memory  \
# 577  Intel Core i7 6820HK 2.7GHz  32  256GB SSD +  1TB HDD
# 224  Intel Core i7 7700HQ 2.8GHz  16  256GB SSD +  1TB HDD
# 78    Intel Core i3 7130U 2.7GHz   4               1TB HDD
# 189   Intel Core i7 8550U 1.8GHz   8  128GB SSD +  1TB HDD
# 372          AMD Ryzen 1700 3GHz  16  256GB SSD +  1TB HDD
#
#                          gpu       opsys  weight        price
# 577  Nvidia GeForce GTX 1070  Windows 10   4.6kg  141884.6400
# 224  Nvidia GeForce GTX 1060  Windows 10  4.42kg  130873.7952
# 78      Nvidia GeForce MX130  Windows 10   2.2kg   28238.4000
# ...

# %%
df['weight'] = df['weight'].str.replace('kg',"")

# %%
df.sample(5)
# Out:
#     company            typename  inches  \
# 940      HP              Gaming    17.3
# 338    Asus            Notebook    15.6
# 265    Dell  2 in 1 Convertible    15.6
# 560    Acer  2 in 1 Convertible    11.6
# 102    Dell            Notebook    15.6
#
#                               screenresolution  \
# 940                IPS Panel Full HD 1920x1080
# 338                                   1366x768
# 265            Full HD / Touchscreen 1920x1080
# 560  IPS Panel Full HD / Touchscreen 1920x1080
# 102                          Full HD 1920x1080
#
#                                       cpu ram                memory  \
# 940           Intel Core i5 6300HQ 2.3GHz   8  128GB SSD +  1TB HDD
# 338  Intel Celeron Dual Core N3350 1.1GHz   4               1TB HDD
# 265            Intel Core i5 8250U 1.6GHz   8             256GB SSD
# 560  Intel Celeron Dual Core N3350 2.0GHz   4    32GB Flash Storage
# 102            Intel Core i5 8250U 1.6GHz   8               1TB HDD
#
# ...

# %%
df['weight']=df['weight'].astype('float64')
df['ram']=df['ram'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   company           1303 non-null   object
#  1   typename          1303 non-null   object
#  2   inches            1303 non-null   float64
#  3   screenresolution  1303 non-null   object
#  4   cpu               1303 non-null   object
#  5   ram               1303 non-null   int64
#  6   memory            1303 non-null   object
#  7   gpu               1303 non-null   object
#  8   opsys             1303 non-null   object
#  9   weight            1303 non-null   float64
#  10  price             1303 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 112.1+ KB

# %%
number_column = df.select_dtypes(include=['int64','float64']).columns
number_column
# Out:
# Index(['inches', 'ram', 'weight', 'price'], dtype='object')

# %%
for i in number_column:
    sns.histplot(df[i],kde=True)
    plt.show()

# %%
sns.countplot(df['company'])
plt.show()

# %%
plt.bar(x=df['company'],height=df['price'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(df['typename'])
plt.show()

# %%
plt.bar(x=df['typename'],height=df['price'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.scatter(y = df['inches'] , x = df['price'])
plt.show()

# %%
df.sample()
# Out:
#     company typename  inches   screenresolution                          cpu  \
# 108     MSI   Gaming    15.6  Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
#
#      ram                memory                         gpu       opsys  \
# 108   16  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1050 Ti  Windows 10
#
#      weight     price
# 108     2.2  69210.72

# %%
df['screenresolution'].value_counts()
# Out:
# screenresolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
df['Touchscreen'] = df['screenresolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.sample(5)
# Out:
#       company            typename  inches  \
# 792    Lenovo  2 in 1 Convertible    13.3
# 127      Asus            Notebook    14.0
# 72       Dell            Notebook    15.6
# 1260   Lenovo  2 in 1 Convertible    14.0
# 862   Toshiba            Notebook    13.3
#
#                                screenresolution                         cpu  \
# 792   IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i7 7500U 2.7GHz
# 127                                    1366x768    AMD E-Series 6110 1.5GHz
# 72                            Full HD 1920x1080  Intel Core i7 8550U 1.8GHz
# 1260            Full HD / Touchscreen 1920x1080  Intel Core i5 6200U 2.3GHz
# 862                           Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
#
#       ram     memory                    gpu         opsys  weight  \
# 792     8  512GB SSD  Intel HD Graphics 620    Windows 10    1.37
# 127     4   64GB SSD          AMD Radeon R2  Windows 10 S    1.65
# ...

# %%
df['Touchscreen'].nunique()
# Out:
# 2

# %%
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# 0    1111
# 1     192
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,4))
sns.countplot(x=df['Touchscreen'])
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.barplot(x=df['Touchscreen'],y=df['price'],errorbar=None)
plt.show()

# %%
df.sample()
# Out:
#     company  typename  inches   screenresolution                         cpu  \
# 138  Lenovo  Notebook    15.6  Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
#
#      ram   memory                   gpu  opsys  weight     price  Touchscreen
# 138    4  1TB HDD  Nvidia GeForce 920MX  No OS     2.2  26586.72            0

# %%
df['IPS Panel']=df['screenresolution'].apply(lambda x : 1 if 'IPS Panel' in x else 0)

# %%
df.sample(5)
# Out:
#        company  typename  inches             screenresolution  \
# 533   Mediacom  Notebook    13.3  IPS Panel Full HD 1920x1080
# 708     Lenovo  Notebook    14.0            Full HD 1920x1080
# 1199       MSI    Gaming    17.3            Full HD 1920x1080
# 1036        HP  Notebook    15.6                     1366x768
# 1242      Acer  Notebook    15.6                     1366x768
#
#                                        cpu  ram                memory  \
# 533   Intel Celeron Quad Core N3450 1.1GHz    4              32GB SSD
# 708            Intel Core i5 6300HQ 2.3GHz    8             256GB SSD
# 1199           Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 1036            Intel Core i5 7200U 2.5GHz    4             500GB HDD
# 1242            Intel Core i3 6006U 2.0GHz    4             500GB HDD
#
#                           gpu       opsys  weight       price  Touchscreen  \
# 533     Intel HD Graphics 500  Windows 10    1.20   19660.320            0
# ...

# %%
plt.figure(figsize=(5,4))
sns.countplot(x=df['IPS Panel'])
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.barplot(x=df['IPS Panel'],y=df['price'],errorbar=None)
plt.show()

# %%
df['full_HD'] = df['screenresolution'].apply(lambda x:1 if 'Full HD' in x else 0)

# %%
df.sample(5)
# Out:
#       company   typename  inches             screenresolution  \
# 1108       HP   Notebook    15.6            Full HD 1920x1080
# 779      Asus   Notebook    15.6                    1920x1080
# 405      Asus  Ultrabook    14.0            Full HD 1920x1080
# 324      Acer   Notebook    15.6                     1366x768
# 531   Toshiba   Notebook    15.6  IPS Panel Full HD 1920x1080
#
#                                        cpu  ram     memory  \
# 1108             AMD A6-Series 9220 2.5GHz    4    1TB HDD
# 779   Intel Pentium Dual Core N4200 1.1GHz    8  128GB SSD
# 405             Intel Core i7 7500U 2.7GHz    8  512GB SSD
# 324            AMD A12-Series 9720P 2.7GHz    8  256GB SSD
# 531             Intel Core i5 7200U 2.5GHz    8  500GB HDD
#
#                         gpu       opsys  weight      price  Touchscreen  \
# 1108          AMD Radeon R4  Windows 10     2.1  21205.440            0
# 779   Intel HD Graphics 505  Windows 10     2.0  31003.632            0
# ...

# %%
df['screenresolution'].value_counts()
# Out:
# screenresolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
df['resolution_only'] = df['screenresolution'].str.extract(r'(\d+x\d+)')

# %%
df.sample(5)
# Out:
#      company   typename  inches             screenresolution  \
# 368     Dell   Notebook    15.6            Full HD 1920x1080
# 550   Lenovo   Notebook    15.6            Full HD 1920x1080
# 1167  Lenovo   Notebook    15.6            Full HD 1920x1080
# 868     Acer   Notebook    14.0  IPS Panel Full HD 1920x1080
# 1275    Asus  Ultrabook    13.3  IPS Panel Full HD 1920x1080
#
#                              cpu  ram     memory                    gpu  \
# 368   Intel Core i7 7500U 2.7GHz    8  256GB SSD     AMD Radeon R7 M445
# 550     Intel Core i3 6006U 2GHz    4  128GB SSD  Intel HD Graphics 520
# 1167    Intel Core i3 6006U 2GHz    4    1TB HDD  Nvidia GeForce 920MX
# 868   Intel Core i5 7200U 2.5GHz    8  256GB SSD  Intel HD Graphics 620
# 1275    Intel Core M 6Y30 0.9GHz    8  512GB SSD  Intel HD Graphics 515
#
#            opsys  weight     price  Touchscreen  IPS Panel  full_HD  \
# 368   Windows 10    2.33  47898.72            0          0        1
# ...

# %%
df[['X', 'Y']] = df['resolution_only'].str.split('x', expand=True)

# %%
df.sample(4)
# Out:
#     company  typename  inches             screenresolution  \
# 248      HP  Notebook    13.3  IPS Panel Full HD 1920x1080
# 754    Asus  Notebook    15.6                     1366x768
# 607  Lenovo  Notebook    15.6            Full HD 1920x1080
# 77     Dell  Notebook    15.6            Full HD 1920x1080
#
#                             cpu  ram                memory  \
# 248  Intel Core i5 8250U 1.6GHz    4             500GB HDD
# 754  Intel Core i7 7500U 2.7GHz    4             256GB SSD
# 607  Intel Core i5 7200U 2.5GHz    6               1TB HDD
# 77   Intel Core i7 8550U 1.8GHz    8  128GB SSD +  1TB HDD
#
#                         gpu       opsys  weight      price  Touchscreen  \
# 248  Intel UHD Graphics 620  Windows 10    1.49  35964.000            0
# 754   Intel HD Graphics 620  Windows 10    2.37  45282.672            0
# 607   Intel HD Graphics 620  Windows 10    2.40  30049.920            0
# 77   Intel UHD Graphics 620  Windows 10    2.02  45554.400            0
#
# ...

# %%
df=df.rename(columns={'opsys':'os_system'})

# %%
df.head()
# Out:
#   company   typename  inches                    screenresolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           cpu  ram               memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             gpu os_system  weight        price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640     macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000     macOS    1.34   47895.5232            0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   company           1303 non-null   object
#  1   typename          1303 non-null   object
#  2   inches            1303 non-null   float64
#  3   screenresolution  1303 non-null   object
#  4   cpu               1303 non-null   object
#  5   ram               1303 non-null   int64
#  6   memory            1303 non-null   object
#  7   gpu               1303 non-null   object
#  8   os_system         1303 non-null   object
#  9   weight            1303 non-null   float64
#  10  price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS Panel         1303 non-null   int64
#  13  full_HD           1303 non-null   int64
#  14  resolution_only   1303 non-null   object
#  15  X                 1303 non-null   object
# ...

# %%
df['X']=df['X'].astype('int64')
df['Y']=df['Y'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   company           1303 non-null   object
#  1   typename          1303 non-null   object
#  2   inches            1303 non-null   float64
#  3   screenresolution  1303 non-null   object
#  4   cpu               1303 non-null   object
#  5   ram               1303 non-null   int64
#  6   memory            1303 non-null   object
#  7   gpu               1303 non-null   object
#  8   os_system         1303 non-null   object
#  9   weight            1303 non-null   float64
#  10  price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS Panel         1303 non-null   int64
#  13  full_HD           1303 non-null   int64
#  14  resolution_only   1303 non-null   object
#  15  X                 1303 non-null   int64
# ...

# %%
df['ppi'] = ((df['X']**2 + df['Y']**2)**0.5) / df['inches']

# %%
df['cpu'].value_counts()
# Out:
# cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu_name'] = df['cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.sample()
# Out:
#     company  typename  inches             screenresolution  \
# 402  Lenovo  Notebook    15.6  IPS Panel Full HD 1920x1080
#
#                             cpu  ram                memory                gpu  \
# 402  Intel Core i5 8250U 1.6GHz    8  256GB SSD +  1TB HDD  AMD Radeon RX 550
#
#       os_system  weight     price  Touchscreen  IPS Panel  full_HD  \
# 402  Windows 10     2.1  60978.96            0          1        1
#
#     resolution_only     X     Y         ppi       Cpu_name
# 402       1920x1080  1920  1080  141.211998  Intel Core i5

# %%
def fetch_processor(text):
    return (
        text if text in ['Intel Core i7','Intel Core i5','Intel Core i3']
        else 'Other Intel Processor' if text.startswith('Intel')
        else 'AMD Processor'
    )

# %%
df['Cpu_Name'] = df['Cpu_name'].apply(fetch_processor)

# %%
df.sample(5)
# Out:
#       company            typename  inches                    screenresolution  \
# 57       Asus            Notebook    15.6                            1366x768
# 825   Toshiba            Notebook    14.0                            1366x768
# 956      Dell  2 in 1 Convertible    13.3     Full HD / Touchscreen 1920x1080
# 4       Apple           Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1025       HP           Ultrabook    12.5                            1366x768
#
#                                        cpu  ram     memory  \
# 57              Intel Core i5 7200U 2.5GHz    4  256GB SSD
# 825   Intel Pentium Dual Core 4405U 2.1GHz    4  128GB SSD
# 956              Intel Core i5 7Y54 1.2GHz    8  256GB SSD
# 4                     Intel Core i5 3.1GHz    8  256GB SSD
# 1025            Intel Core i5 7200U 2.5GHz    4  256GB SSD
#
#                                gpu   os_system  weight        price  \
# 57           Intel HD Graphics 620  Windows 10    2.00   31232.2032
# ...

# %%
sns.countplot(df['Cpu_Name'])
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.barplot(x=df['Cpu_Name'],y=df['price'],errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
df['ram'].value_counts().plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.barplot(x=df['ram'],y=df['price'],errorbar=None)
plt.show()

# %%
df['memory'].value_counts()
# Out:
# memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['memory'] = df['memory'].astype(str).replace('\.0', '', regex=True)
df["memory"] = df["memory"].str.replace('GB', '')
df["memory"] = df["memory"].str.replace('TB', '000')

new = df["memory"].str.split("+", n = 1, expand = True)

df["first"] = new[0].str.strip()
df["second"] = new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '', regex=True)

df["second"].fillna("0", inplace=True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '', regex=True)

# ⭐ FIX HERE: avoid empty '' errors
df['first'] = df['first'].fillna('0').replace('', '0')
df['second'] = df['second'].fillna('0').replace('', '0')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"] = df["first"]*df["Layer1HDD"] + df["second"]*df["Layer2HDD"]
df["SSD"] = df["first"]*df["Layer1SSD"] + df["second"]*df["Layer2SSD"]
df["Hybrid"] = df["first"]*df["Layer1Hybrid"] + df["second"]*df["Layer2Hybrid"]
df["Flash_Storage"] = df["first"]*df["Layer1Flash_Storage"] + df["second"]*df["Layer2Flash_Storage"]

df.drop(columns=[
    'first','second','Layer1HDD','Layer1SSD','Layer1Hybrid','Layer1Flash_Storage',
    'Layer2HDD','Layer2SSD','Layer2Hybrid','Layer2Flash_Storage'
], inplace=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\rajus\AppData\Local\Temp\ipykernel_22164\2243335964.py:1: SyntaxWarning: invalid escape sequence '\.'
#   df['memory'] = df['memory'].astype(str).replace('\.0', '', regex=True)
# C:\Users\rajus\AppData\Local\Temp\ipykernel_22164\2243335964.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["second"].fillna("0", inplace=True)

# %%
df.sample(5)
# Out:
#      company   typename  inches             screenresolution  \
# 1049    Asus    Netbook    11.6                     1366x768
# 522     Dell   Notebook    14.0            Full HD 1920x1080
# 399   Lenovo  Ultrabook    14.0          IPS Panel 2560x1440
# 649   Lenovo  Ultrabook    12.5  IPS Panel Full HD 1920x1080
# 699       HP   Notebook    15.6  IPS Panel Full HD 1920x1080
#
#                                        cpu  ram            memory  \
# 1049  Intel Celeron Dual Core N3060 1.6GHz    4  16 Flash Storage
# 522             Intel Core i5 7300U 2.6GHz    8           256 SSD
# 399             Intel Core i7 7500U 2.7GHz   16          1000 SSD
# 649             Intel Core i7 7500U 2.7GHz    8           256 SSD
# 699             Intel Core i7 7500U 2.7GHz    4           500 HDD
#
#                         gpu   os_system  weight  ...  resolution_only     X  \
# 1049  Intel HD Graphics 400   Chrome OS    1.20  ...         1366x768  1366
# ...

# %%
df=df.drop('memory',axis=1)

# %%
df.sample()
# Out:
#      company  typename  inches   screenresolution                         cpu  \
# 1062    Dell  Notebook    15.6  Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
#
#       ram                gpu   os_system  weight     price  ...  \
# 1062    4  Intel HD Graphics  Windows 10    2.25  29783.52  ...
#
#       resolution_only     X     Y         ppi       Cpu_name       Cpu_Name  \
# 1062        1920x1080  1920  1080  141.211998  Intel Core i5  Intel Core i5
#
#        HDD SSD Hybrid  Flash_Storage
# 1062  1000   0      0              0
#
# [1 rows x 23 columns]

# %%
df.drop(columns=['inches','X','Y'],inplace=True)

# %%
df.drop(columns=['screenresolution','resolution_only'],inplace=True)

# %%
df.drop(columns=['Hybrid','Flash_Storage','Cpu_name','cpu'],inplace=True)

# %%
df.sample()
# Out:
#     company  typename  ram                    gpu   os_system  weight  \
# 582      HP  Notebook    4  Intel HD Graphics 620  Windows 10    1.49
#
#         price  Touchscreen  IPS Panel  full_HD         ppi       Cpu_Name  \
# 582  38308.32            0          0        1  165.632118  Intel Core i3
#
#      HDD  SSD
# 582    0  128

# %%
df['gpu_brand'] = df['gpu'].apply(lambda x:x.split()[0])

# %%
df.sample()
# Out:
#     company            typename  ram                   gpu   os_system  \
# 674      HP  2 in 1 Convertible    4  Nvidia GeForce 940MX  Windows 10
#
#      weight     price  Touchscreen  IPS Panel  full_HD         ppi  \
# 674    1.63  37242.72            1          1        1  157.350512
#
#           Cpu_Name  HDD  SSD gpu_brand
# 674  Intel Core i3    0  128    Nvidia

# %%
df['gpu_brand'].value_counts()
# Out:
# gpu_brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df=df[df['gpu_brand']!='ARM']

# %%
df['gpu_brand'].value_counts()
# Out:
# gpu_brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,4))
sns.barplot(x=df['gpu_brand'],y=df['price'],errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
df=df.drop('gpu',axis=1)

# %%
df.sample()
# Out:
#     company  typename  ram os_system  weight     price  Touchscreen  \
# 281    Dell  Notebook    4     Linux    2.25  22803.84            0
#
#      IPS Panel  full_HD         ppi       Cpu_Name   HDD  SSD gpu_brand
# 281          0        1  141.211998  Intel Core i3  1000    0       AMD

# %%
df['os_system'].value_counts()
# Out:
# os_system
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
df['os_system'].replace({'Windows 10':'Windows','Windows 7':'Windows','Windows 10 S':'Windows','macOS':'Mac','Mac OS X':'Mac'},inplace=True)
# Out:
# C:\Users\rajus\AppData\Local\Temp\ipykernel_22164\1958779102.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['os_system'].replace({'Windows 10':'Windows','Windows 7':'Windows','Windows 10 S':'Windows','macOS':'Mac','Mac OS X':'Mac'},inplace=True)

# %%
df['os_system'].value_counts()
# Out:
# os_system
# Windows      1125
# No OS          66
# Linux          62
# Chrome OS      26
# Mac            21
# Android         2
# Name: count, dtype: int64

# %%
df['os_system'].replace({'No OS':"Other/No OS/Linux","Linux":"Other/No OS/Linux",'Chrome OS':"Other/No OS/Linux",'Android':"Other/No OS/Linux"},inplace=True)

# %%
df['os_system'].value_counts()
# Out:
# os_system
# Windows              1125
# Other/No OS/Linux     156
# Mac                    21
# Name: count, dtype: int64

# %%
sns.barplot(x=df['os_system'],y=df['price'],errorbar=None)
plt.show()

# %%
df.sample()
# Out:
#     company     typename  ram os_system  weight      price  Touchscreen  \
# 398    Dell  Workstation    8   Windows    1.78  144495.36            1
#
#      IPS Panel  full_HD         ppi       Cpu_Name  HDD  SSD gpu_brand
# 398          0        0  282.423996  Intel Core i7    0  256    Nvidia

# %%
sns.histplot(df['weight'],kde=True)
plt.show()

# %%
sns.scatterplot(x=df['weight'],y=df['price'])
plt.show()

# %%
df.sample()
# Out:
#      company  typename  ram os_system  weight     price  Touchscreen  \
# 1207  Lenovo  Notebook    4   Windows     2.2  15930.72            0
#
#       IPS Panel  full_HD        ppi       Cpu_Name  HDD  SSD gpu_brand
# 1207          0        0  100.45467  AMD Processor  500    0       AMD

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1302 entries, 0 to 1302
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   company      1302 non-null   object
#  1   typename     1302 non-null   object
#  2   ram          1302 non-null   int64
#  3   os_system    1302 non-null   object
#  4   weight       1302 non-null   float64
#  5   price        1302 non-null   float64
#  6   Touchscreen  1302 non-null   int64
#  7   IPS Panel    1302 non-null   int64
#  8   full_HD      1302 non-null   int64
#  9   ppi          1302 non-null   float64
#  10  Cpu_Name     1302 non-null   object
#  11  HDD          1302 non-null   int64
#  12  SSD          1302 non-null   int64
#  13  gpu_brand    1302 non-null   object
# dtypes: float64(3), int64(6), object(5)
# memory usage: 152.6+ KB

# %%
num=df.select_dtypes(include=['int64','float64']).columns
num
# Out:
# Index(['ram', 'weight', 'price', 'Touchscreen', 'IPS Panel', 'full_HD', 'ppi',
#        'HDD', 'SSD'],
#       dtype='object')

# %%
df[num].corr().round(2)
# Out:
#               ram  weight  price  Touchscreen  IPS Panel  full_HD   ppi   HDD  \
# ram          1.00    0.38   0.74         0.12       0.21     0.21  0.31  0.10
# weight       0.38    1.00   0.21        -0.29       0.02     0.15 -0.32  0.51
# price        0.74    0.21   1.00         0.19       0.25     0.20  0.48 -0.10
# Touchscreen  0.12   -0.29   0.19         1.00       0.15    -0.10  0.46 -0.21
# IPS Panel    0.21    0.02   0.25         0.15       1.00     0.19  0.30 -0.09
# full_HD      0.21    0.15   0.20        -0.10       0.19     1.00 -0.01  0.01
# ppi          0.31   -0.32   0.48         0.46       0.30    -0.01  1.00 -0.29
# HDD          0.10    0.51  -0.10        -0.21      -0.09     0.01 -0.29  1.00
# SSD          0.60   -0.06   0.67         0.26       0.23     0.20  0.51 -0.40
#
#               SSD
# ram          0.60
# weight      -0.06
# price        0.67
# Touchscreen  0.26
# IPS Panel    0.23
# full_HD      0.20
# ppi          0.51
# HDD         -0.40
# ...

# %%
plt.figure(figsize=(8,5))
sns.heatmap(df[num].corr(),cmap='rainbow',fmt='.2f',annot=True,linewidths=0.1)
plt.show()

# %%
sns.histplot((df['price']))
plt.show()

# %%
sns.histplot(np.log(df['price']))
plt.show()

# %%
df.sample(5)
# Out:
#     company   typename  ram          os_system  weight       price  \
# 52       HP   Notebook    4            Windows    1.86  21231.5472
# 300    Asus   Notebook    4            Windows    1.30  27119.5200
# 790    Asus     Gaming    8            Windows    2.24  71341.9200
# 850      HP   Notebook    4  Other/No OS/Linux    1.86  15930.7200
# 384    Asus  Ultrabook   16            Windows    1.10  93181.3920
#
#      Touchscreen  IPS Panel  full_HD         ppi               Cpu_Name   HDD  \
# 52             0          0        1  141.211998          AMD Processor     0
# 300            0          0        0  111.935204          Intel Core i3     0
# 790            0          0        1  141.211998          Intel Core i7  1000
# 850            0          0        0  100.454670  Other Intel Processor     0
# 384            1          0        1  165.632118          Intel Core i7     0
#
#      SSD gpu_brand
# 52   256       AMD
# 300  128     Intel
# 790  128    Nvidia
# ...

# %%
X = df.drop(columns=['price'])
y = np.log(df['price'])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=2)

# %%
X.head()
# Out:
#   company   typename  ram          os_system  weight  Touchscreen  IPS Panel  \
# 0   Apple  Ultrabook    8                Mac    1.37            0          1
# 1   Apple  Ultrabook    8                Mac    1.34            0          0
# 2      HP   Notebook    8  Other/No OS/Linux    1.86            0          0
# 3   Apple  Ultrabook   16                Mac    1.83            0          1
# 4   Apple  Ultrabook    8                Mac    1.37            0          1
#
#    full_HD         ppi       Cpu_Name  HDD  SSD gpu_brand
# 0        0  226.983005  Intel Core i5    0  128     Intel
# 1        0  127.677940  Intel Core i5    0    0     Intel
# 2        1  141.211998  Intel Core i5    0  256     Intel
# 3        0  220.534624  Intel Core i7    0  512       AMD
# 4        0  226.983005  Intel Core i5    0  256     Intel

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

# %%
step1 = ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first', sparse_output=False),[0, 1, 3, 9, 12])],remainder='passthrough')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score , mean_absolute_error

# %%
pipe = Pipeline([
    ('step1',step1),
    ('step2',LinearRegression())
])
pipe.fit(X_train,y_train)

ypred = pipe.predict(X_test)

print('r2_score',r2_score(y_test,ypred))
print('mean_absolute_error',mean_absolute_error(y_test,ypred))
# Out:
# r2_score 0.8080868053193602
# mean_absolute_error 0.21140659941338907

# %%
from xgboost import XGBRegressor

step1 = ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first', sparse_output=False),[0, 1, 3, 9, 12])],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8881127329220455
# MAE 0.15350661791188042

# %%
import pickle

pickle.dump(df, open('df.pkl','wb'))
pickle.dump(pipe, open('pipe.pkl','wb'))
